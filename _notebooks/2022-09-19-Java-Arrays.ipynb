// %% [markdown]
// # Java Arrays
// > Arrays with 2D images as text.
//
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter,week-4]

// %% [markdown]
// ## Teddy Bear Loop
//
// - Loops through a loop using an array of teddy bears of different designs until there's no more left in the store.

// %%
class TeddyLoop {
    //The area between class definition and the 1st method is where we keep data for object in Java
    String [][] teddys;    //2D Array: AP CSA Unit 8: 2D array of strings
                            //2D array is like a grid [x][y]
                            // or like a spreadsheet [row][column]

    /**
     * Constructor initializes a 2D array of teddys
     */
    public TeddyLoop() {
        //Storing Data in 2D arrays
        teddys = new String[][]{   //2D array above is just a name, "new" makes a container ("object")
                //Teddy 0
                {
                    "      ___",
                    "    {~._.~}",
                    "     ( Y )",
                    "    ()~*~()",
                    "    (_)-(_)"
                },
                //Teddy 1
                {
                    "     ()=()",       //[1][0]
                    "     ('Y')",
                    "     q . p",
                    "     ()_() "
                },
                //Teddy 2
                {
                    "     ()=()",       //[2][0]
                    "     (':')",
                    "     d . b",
                    "     ()_() "
                },
                //Teddy 3
                {
                    "     ()-()",        //[3][0]
                    "     (^;^)",
                    "     C   C ",
                    "     ()_() "
                },
                //Teddy 4
                {
                    "     ()-()",          //[4][0]
                    "     ('&')",          //[4][1]
                    "     c . c",          //[4][2]
                    "     ()_()"           //[4][3]
                },

        };
    }

    /**
     * Loop and print teddys in array
     * ... repeat until you reach zero  ...
     */
    public void printPoem() {
        //begin the poem
        System.out.println();
        System.out.println("5 distraught Teddy Bears in a Store.\nHow many bought? How many more?");

        // teddys (non-primitive) defined in constructor knows its length
        int teddyCount = teddys.length;
        for (int i = teddyCount; i >= 1; i--)  //loops through 2D array length backwards
        {

            //this print statement shows current count of teddys
            if(i == 1) {//  concatenation (+) of the loop variable and string to form a countdown message
                System.out.println("Oh no! " + i + " Teddy Bear left!");
            }
            else if(i == 2) {
                System.out.println("Just " + i + " Teddy Bears left!");
            }
            else if(i == 3) {
                System.out.println("Only " + i + " Teddy Bears left!");
            }
            else if(i == 4) {
                System.out.println("Still " + i + " Teddy Bears left!");
            }
            else {
                System.out.println("Luckily there's " + i + " Teddy Bears left!");
            }
            //how many separate parts are there in a teddy teddy?
            for (int row = 0; row < teddyCount; row++) {  //cycles through "cells" of 2d array

                /*cycles through columns to print
                each teddy part by part, will eventually print entire column*/
                for (int col = 0; col < teddys[row].length; col++) {

                    // prints specific part of the teddy from the column
                    System.out.print(teddys[row][col] + " ");

                    //this is new line between separate parts
                    System.out.println();
                }

                //this new line gives separation between stanza of poem
                System.out.println();
            }

            //countdown for poem, decrementing teddyCount variable by 1
            teddyCount -= 1;
        }

        //out of all the loops, prints finishing messages
        System.out.println("All the teddy bears out the door. :(");
        System.out.println("----------------------------------");
        System.out.println("             THE END              ");
    }

    /**
    * A Java Driver/Test method that is the entry point for execution
    */
    public static void main(String[] args)  {
        new TeddyLoop().printPoem();   //a new teddy list and output in one step
    }

}
TeddyLoop.main(null);
// Out:
// 5 distraught Teddy Bears in a Store.
// How many bought? How many more?
// Luckily there's 5 Teddy Bears left!
//       ___
//     {~._.~}
//      ( Y )
//     ()~*~()
//     (_)-(_)
//
//      ()=()
//      ('Y')
//      q . p
//      ()_()
//
//      ()=()
//      (':')
//      d . b
//      ()_()
//
//      ()-()
//      (^;^)
//      C   C
//      ()_()
//
//      ()-()
//      ('&')
//      c . c
//      ()_()
//
// Still 4 Teddy Bears left!
//       ___
//     {~._.~}
//      ( Y )
//     ()~*~()
//     (_)-(_)
//
//      ()=()
//      ('Y')
//      q . p
//      ()_()
//
//      ()=()
//      (':')
//      d . b
//      ()_()
//
//      ()-()
//      (^;^)
//      C   C
//      ()_()
//
// Only 3 Teddy Bears left!
//       ___
//     {~._.~}
//      ( Y )
//     ()~*~()
//     (_)-(_)
//
//      ()=()
//      ('Y')
//      q . p
//      ()_()
//
//      ()=()
//      (':')
//      d . b
//      ()_()
//
// Just 2 Teddy Bears left!
//       ___
//     {~._.~}
//      ( Y )
//     ()~*~()
//     (_)-(_)
//
//      ()=()
//      ('Y')
//      q . p
//      ()_()
//
// Oh no! 1 Teddy Bear left!
//       ___
//     {~._.~}
//      ( Y )
//     ()~*~()
//     (_)-(_)
//
// All the teddy bears out the door. :(
// ----------------------------------
//              THE END
