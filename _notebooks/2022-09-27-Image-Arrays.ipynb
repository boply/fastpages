// %% [markdown]
// # Java Image Arrays
// > Arrays converting 2D images as text.
//
// - toc: true
// - badges: true
// - comments: true
// - categories: [jupyter,week-6]

// %% [markdown]
// Mona Lisa and Pumpkin to Text (ASCII)

// %%
import java.awt.Color;
import java.awt.image.BufferedImage;
import java.awt.Image;
import java.awt.Graphics2D;

import java.io.File;
import java.io.FileWriter;
import java.io.IOException;
import java.io.PrintWriter;
import java.nio.file.Files;
import java.nio.file.Path;
import java.nio.file.Paths;

import javax.imageio.stream.ImageOutputStream;
import javax.imageio.stream.ImageInputStream;
import javax.imageio.metadata.IIOMetadata;
import javax.imageio.IIOImage;
import javax.imageio.ImageIO;
import javax.imageio.ImageWriteParam;
import javax.imageio.ImageWriter;
import javax.imageio.ImageReader;
import javax.imageio.ImageTypeSpecifier;

public class Pics {
    private final String inDir = "images/"; // location of images
    private final String outDir = "images/tmp/";  // location of created files
    private String inFile;
    private String resizedFile;
    private String asciiFile;
    private String ext;   // extension of file
    private long bytes;
    private int width;
    private int height;

    // Constructor obtains attributes of picture
    public Pics(String name, String ext) {
        this.ext = ext;
        this.inFile = this.inDir + name + "." + ext;
        this.resizedFile = this.outDir + name + "." + ext;
        this.asciiFile = this.outDir + name + ".txt";
        this.setStats();
    }

    
    // An image contains metadata, namely size, width, and height
    public void setStats() {
        BufferedImage img;
        try {
            Path path = Paths.get(this.inFile);
            this.bytes = Files.size(path);
            img = ImageIO.read(new File(this.inFile));
            this.width = img.getWidth();
            this.height = img.getHeight();
        } catch (IOException e) {
        }
    }

    // Console print of data
    public void printStats(String msg) {
        System.out.println(msg + ": " + this.bytes + " " + this.width + "x" + this.height + "  " + this.inFile);
    }

    // Convert scaled image into buffered image
    public static BufferedImage convertToBufferedImage(Image img) {

        // Create a buffered image with transparency
        BufferedImage bi = new BufferedImage(
                img.getWidth(null), img.getHeight(null),
                BufferedImage.TYPE_INT_ARGB);

        // magic?
        Graphics2D graphics2D = bi.createGraphics();
        graphics2D.drawImage(img, 0, 0, null);
        graphics2D.dispose();

        return bi;
    }
    
    // Scale or reduce to "scale" percentage provided
    public void resize(int scale) {
        BufferedImage img = null;
        Image resizedImg = null;  

        int width = (int) (this.width * (scale/60.0) + 0.5);
        int height = (int) (this.height * (scale/160.0) + 0.5);

        try {
            // read an image to BufferedImage for processing
            img = ImageIO.read(new File(this.inFile));  // set buffer of image data
            // create a new BufferedImage for drawing
            resizedImg = img.getScaledInstance(width, height, Image.SCALE_SMOOTH);
        } catch (IOException e) {
            return;
        }

        try {
            ImageIO.write(convertToBufferedImage(resizedImg), this.ext, new File(resizedFile));
        } catch (IOException e) {
            return;
        }
        
        this.inFile = this.resizedFile;  // use scaled file vs original file in Class
        this.setStats();
    }
    
    // convert every pixel to an ascii character (ratio does not seem correct)
    public void convertToAscii() {
        BufferedImage img = null;
        PrintWriter asciiPrt = null;
        FileWriter asciiWrt = null;

        try {
            File file = new File(this.asciiFile);
            Files.deleteIfExists(file.toPath()); 
        } catch (IOException e) {
            System.out.println("Delete File error: " + e);
        }

        try {
            asciiPrt = new PrintWriter(asciiWrt = new FileWriter(this.asciiFile, true));
        } catch (IOException e) {
            System.out.println("ASCII out file create error: " + e);
        }

        try {
            img = ImageIO.read(new File(this.inFile));
        } catch (IOException e) {
        }

        for (int i = 0; i < img.getHeight(); i++) {
            for (int j = 0; j < img.getWidth(); j++) {
                Color col = new Color(img.getRGB(j, i));
                double pixVal = (((col.getRed() * 0.30) + (col.getBlue() * 0.59) + (col
                        .getGreen() * 0.11)));
                try {
                    asciiPrt.print(asciiChar(pixVal));
                    asciiPrt.flush();
                    asciiWrt.flush();
                } catch (Exception ex) {
                }
            }
            try {
                asciiPrt.println("");
                asciiPrt.flush();
                asciiWrt.flush();
            } catch (Exception ex) {
            }
        }
    }

    // conversion table, there may be better out there ie https://www.billmongan.com/Ursinus-CS173-Fall2020/Labs/ASCIIArt
    public String asciiChar(double g) {
        String str = " ";
        if (g >= 240) {
            str = " ";
        } else if (g >= 237) {
            str = "`";
        } else if (g >= 235) {
            str = ".";
        } else if (g >= 232) {
            str = "'";
        } else if (g >= 230) {
            str = "-";
        } else if (g >= 227) {
            str = ",";
        } else if (g >= 225) {
            str = ":";
        } else if (g >= 222) {
            str = "\"";
        } else if (g >= 220) {
            str = "~";
        } else if (g >= 217) {
            str = "^";
        } else if (g >= 214) {
            str = ";";
        } else if (g >= 212) {
            str = "!";
        } else if (g >= 210) {
            str = "_";
        } else if (g >= 207) {
            str = "*";
        } else if (g >= 205) {
            str = "/";
        } else if (g >= 202) {
            str = "(";
        } else if (g >= 200) {
            str = "r";
        } else if (g >= 198) {
            str = ")";
        } else if (g >= 196) {
            str = "|";
        } else if (g >= 193) {
            str = "+";
        } else if (g >= 191) {
            str = ">";
        } else if (g >= 188) {
            str = "<";
        } else if (g >= 185) {
            str = "]";
        } else if (g >= 182) {
            str = "[";
        } else if (g >= 180) {
            str = "l";
        } else if (g >= 178) {
            str = "L";
        } else if (g >= 175) {
            str = "Y";
        } else if (g >= 173) {
            str = "j";
        } else if (g >= 170) {
            str = "=";
        } else if (g >= 168) {
            str = "c";
        } else if (g >= 165) {
            str = "7";
        } else if (g >= 162) {
            str = "1";
        } else if (g >= 160) {
            str = "i";
        } else if (g >= 158) {
            str = "T";
        } else if (g >= 156) {
            str = "J";
        } else if (g >= 154) {
            str = "t";
        } else if (g >= 152) {
            str = "}";
        } else if (g >= 150) {
            str = "n";
        } else if (g >= 147) {
            str = "f";
        } else if (g >= 145) {
            str = "x";
        } else if (g >= 143) {
            str = "{";
        } else if (g >= 140) {
            str = "u";
        } else if (g >= 138) {
            str = "C";
        } else if (g >= 136) {
            str = "s";
        } else if (g >= 133) {
            str = "z";
        } else if (g >= 130) {
            str = "y";
        } else if (g >= 128) {
            str = "V";
        } else if (g >= 126) {
            str = "F";
        } else if (g >= 124) {
            str = "h";
        } else if (g >= 122) {
            str = "o";
        } else if (g >= 120) {
            str = "w";
        } else if (g >= 117) {
            str = "k";
        } else if (g >= 115) {
            str = "%";
        } else if (g >= 112) {
            str = "U";
        } else if (g >= 110) {
            str = "4";
        } else if (g >= 107) {
            str = "X";
        } else if (g >= 105) {
            str = "3";
        } else if (g >= 102) {
            str = "S";
        } else if (g >= 100) {
            str = "P";
        } else if (g >= 98) {
            str = "K";
        } else if (g >= 96) {
            str = "e";
        } else if (g >= 94) {
            str = "Z";
        } else if (g >= 92) {
            str = "G";
        } else if (g >= 90) {
            str = "H";
        } else if (g >= 87) {
            str = "A";
        } else if (g >= 85) {
            str = "5";
        } else if (g >= 83) {
            str = "O";
        } else if (g >= 81) {
            str = "D";
        } else if (g >= 78) {
            str = "$";
        } else if (g >= 76) {
            str = "d";
        } else if (g >= 74) {
            str = "0";
        } else if (g >= 72) {
            str = "E";
        } else if (g >= 70) {
            str = "Q";
        } else if (g >= 68) {
            str = "R";
        } else if (g >= 66) {
            str = "9";
        } else if (g >= 64) {
            str = "&";
        } else if (g >= 62) {
            str = "6";
        } else if (g >= 60) {
            str = "N";
        } else if (g >= 58) {
            str = "M";
        } else if (g >= 56) {
            str = "W";
        } else if (g >= 54) {
            str = "B";
        } else if (g >= 52) {
            str = "#";
        } else {
            str = "@";
        }
        return str;
    }

    // tester/driver
    public static void main(String[] args) throws IOException {
        Pics monaLisa = new Pics("MonaLisa", "png");
        monaLisa.printStats("Original");
        monaLisa.resize(33);
        monaLisa.printStats("Scaled");
        monaLisa.convertToAscii();

        Pics pumpkin = new Pics("pumpkin", "png");
        pumpkin.printStats("Original");
        pumpkin.resize(33);
        pumpkin.printStats("Scaled");
        pumpkin.convertToAscii();
    }
}
Pics.main(null);
// Out:
// Original: 499298 389x413  images/MonaLisa.png
// Scaled: 58149 214x85  images/tmp/MonaLisa.png
// Original: 39392 302x265  images/pumpkin.png
// Scaled: 10416 166x55  images/tmp/pumpkin.png

// %% [markdown]
// # Print .txt File

// %%
try (BufferedReader br = new BufferedReader(new FileReader("images/tmp/MonaLisa.txt"))) {
    String line;
    while ((line = br.readLine()) != null) {
        System.out.println(line);
    }
    System.out.println();
 }
 try (BufferedReader br = new BufferedReader(new FileReader("images/tmp/Pumpkin.txt"))) {
    String line;
    while ((line = br.readLine()) != null) {
        System.out.println(line);
    }
 }
// Out:
// ";"!^"";;;__/_""*"~^;_(~~^;,;(~^;~(()[PzoRd$O0d$O$O5GHGAOoU3PK333%k%%whkoFFsyufi{{ln[i7iYfuxnnyz{{wXwVFU3k4SK3P4eeXZG5UeOd0E$D$D0G5d5$EQE5Q0ERQ$9$&6R&M6@&WNB@Q@@&9$RQ#@B@@@@@@@B@M@@@@@@#E@@9@@B@@@@@#@@@W@@@@@$H{=j]
// !!;r/**^_^"^*^^~,^,"*_^!"^*~^(~~;**|CChD$dHZGKD5$DZDAHHK3okU3wkkhVsVffYYj[l[[]<7=cr})L]++[+l(j[jj71u7}nit1i1fJnuuuuyFhXX5AA0QDQ00$$R0D0ddDQEOdM$90d&d@N&@9W@#@M@#B$9QRR&@@@@@@@@B@@@@MN@@@#@@Q@@@@@@#@@@@@W@@@@@BW@dy1
// /_!r^^!^^;"^";"""~";!_"~;~^^^!"^(|YoySAPKeePHeAHeAKK3kkyFx1cJTYLL7>[L>|/+_];();/j(]*]*+"+!>|[l][+]<7>[l[iYY1}c1fiTTT}}T}kowXePkZAAAU9HO$OQE0d6d5&0$6EM9&BE&&EMO@B@WRBW@@#@@@@#@@@@W@@B@6@N@@@@@@@@@@@@@@@@NQ@@@@$@N@@D
// (;^;^^^";:""":,",^,~^_""",;~;;^!<}USHGXP5ZHADdOPUo{f7777Yl>c>/++()(>"<*~r;;r(;r:lrr(;];!,L;r></7/>/T>L<]7)<LnLLi71=7JiTxzuCCko3UXKHAEH0dGddAdQRRdRR9dEdd#AW@6Q6@AB9@@@#@@B@@@B@@@#@@@@@@@@@@@@B@@@@B@@@@@@@#@#@@6@@@@@
// ;^"^~"",;',-"^--_,,~;,,::"*;)/r+4X5ZSAAAOHHH4FnJtJ7=7Y[)[*/!^>"/)~)!~(");^);!+_;,!!*()<r|+(*+Y;[++(>=+Y(j>Y[Jt]f=TJi}1=tfix1nwU4o3eU0eOOGA$555RQO$HR0EM9MONQQ$NMB#MNR@#@@@@B@@@@M#@@64H@N@@@@@M@@@@@@@@@N@@@@@@@N@@@@@
// ^~:";:",~:'~"_""*:";;";~;!;<+;nsO5O000dOHSUyu{TtJic>]Y|*c)ll*ir>/(|L_!;j;*"",:(;" Y.,:-"]'r.L'_r)r^![>(+<L+l|f|iLx]=JY7{u1ufxshFV%3GGKGKPd5GKHHGP65MD00E&G@M@$@B6BWB9@@@@M@@@@M@@@@@@#@@@@@@@@M@@N@@@R@@#@@@@@@@#@@@@@
// ,:":",:,"'-,,~("-:;;!,)^!r/(YXPZKK$$OHHGXyz{tciiTfcnnni(}~/_"/|`^".^!.:+,`",,'!~;-_;",:.)`+';^,;_+""^>"(^]()/=_ll7*l<]YfYL1nufsfzFkykh4XGeZAKK55DdDQ09R0NQ9&9dBB0#&R@NEM@W@##W@@@@B@@@@#M@@@@#W9@@@@@d@@@@BW@@@@M@@@@@
// :,,",,,:-,'^~"*",,;"|-r*()>1oXKe$G5$ek%yVyVffC}=L1)Y>)<:Y-^^` * .] :,,`'~':.,.*:> |;'`''; !`.+',+^;";+"/->!/(+;])<*|)r>+[lL7jtiCxxzhFoykUXUXXXG5ZSOAOR&90&A&&H5NWBWd#NBNBB@M@B@@@@@@@@@@6@W@B@@D@@@W@E@@M@@$6@@@O@@@@@
// "',^:''--,',-,-'::~^<^+*<l{SeODS5ZHDHPSFyi17[L7[+Y;r;+``(.:`, ~":-/ ^:` |``*'".,.,"~_  `;`^^.;' /.:^.;/^_[;<_|!>r|~+r+<]L]]=cifCuJuufFkPwP%%XeS0HZHK$$DOdM06N6E6dRMQ@#M@@@#@@@@@@@@@@@@@@@@@@@@W@@@@@9@@B@@@@@@@$@@@@@
// "-",^'-"':"^~:"""_*!r/][fUZ$EPA9EEA5eohntT7[Y>]</<**;~"r^`- :`~~ ^~^ *  ~, /.,`" ~'r,, ", `( `(,~~`(,:*'*(!^*!;>(*()(<>><Y<YY7cJiJfnzFwXVwKPXwXPOA5A$$5&E9&#09ONNB@#@@N@@@@@@@@@@@@@@@@@@@@@@@#@@@@@@@@@@@@@@@@@Q@@@@@
// ,:,:":::^"~~,:::^"**+|nf4HSd9W6$5HKwFsfT17=>L+>)(+-;' '_-'`'. ~~"_`( ._ ^:',* `!~' !`;".'/`;``~::;  * ;,;!!^Y~/;]*j!))+</<>[]=[c7JTf}VCoFyk4kV4KPAAKeAH0AERN&6d9Q9NW&@BN&@@@@@@@@@@@@@@@@@@@@@@B@@@@N@@@@@@@@@@@M@@@@@
// :'",-;-,,":~~""^"*!]Y1zAW@Q9R$R9A5K3sxt7Ll<Y|[(*;(("-: |:" `` _.:*',^.* :!,-)  :*  < `,_ (.'(`"`'~` (`^-^,;^/!:*^])(//>|/>|>]lcl7c1TffuyhwwkoU4SePPDSOO$e&09Q9E6QQR60@6#@@@@@@@@@@@@@@@@@@R#@@@@@@@@@@@@@@@@@@@@@@@@@@
// '.'::-~'',"",^:_r(|=7HN&Q5NE6RNAS%kFsuu1Y7lj]+((+^*:`-`*`^::,-_` _` . c'.| (;^`-^.'(-",(:'* *,`.!"`',,~^,"_-,*:^^*/(*/r^_r++]<YlYYiJfnCzkw4UwUUSPZ3APAZ$4O5EO0dQ&9EW0@@N&NB@@@M#@#@@@#@@B@@@@@@@@@@@@@@@@@&@@@@9@@#@@@
// ,,',-'-'"^^^"~~!/rJ4GH9d$9QDOR$PPUyz}1uJ=7=[]*)^;;"".,.),~''`-:'.(``- =  / -/~,'^'`>`,`; .+.",,`,",~,;~-^,!,",*^^;r^/*()r+++<l]=LciiCnuykkkPUwF4Xe4ZXHSGkGH$D$OSD99R9R&M69BWB@9@&@5#@@M@@@@W@@@@@@@@@B@@@@W@@@@W@@@@H@
// --',-,_-,,::"^;^{oXozREQ$OQ&dMSeKFys}{Y7[c+Y<>]^^^"^",,^`-,-,.(`"^`'' *, + ./--^;,`(-.:`:',:.'/''-::,/_,r"_"!~!*;/(!)!/(>++><<cL=l1}fJfnkfz%hUw3S3Xk3PZHS$HQADD5EQE6EQ6&6Q@BBR@@N#BBW@BNDW@@@@@@@@@@M@6#@@@@@@@E@@@@B@
// ,'-,,-',,,--->=nszJVX3RN000&WNGHSkyft1c7l[L]+Yr);*;~"'^.`-.:".( 'r-"":[  *,'(~"*;:!'',_ ,`^```r^^-r-:_;"";^,"!|_(^r^;(*l(|>+7L=TY=TTnJu}fuozwFo%%ZZUK%5SkXXZ0AO3AA$$E6&R6Q9W@RMWR9@@6N@QB@#MBM#@@@@@B@&B#@M@@@@@@@@@@@
// ''-,'":^,":!CJt=TuCC4ddB&d@DN6GDekyo{Jijj<Y+|+*|;(;,;',,-',,~r:'.-l-,'Y.`<^~.c.>^"<', ! `.*/-,*"",!',(,",;"^"_+/*_*>(r/[][LLt}[ic1i}i1C{uu{uFuhs%UPU4FH3KSA4PKEUO$$E69EEW$9B@WQBNW@@@@@@N@@@@@Q#@@@@@@BM@@@@@@@@@@@@@@
// '-,'.'',-~=zi=Tf}xk%UEW6R@BQR9OSZXhVufc=[[l>[]>|(+r~^',~~^^')r,:.r:*;"7";)*_;[,"/,<':`_.':*:*_:|~!,/^;~~"^_^;^[([)*l(L+ln[[[jnl7j=f==T}n7sFkCuUFwUookyZwAXPKPG5UOAAOE$d&9EdR&#@@@B@@@B@BN@B@@@@R@B@@B@B@@@@@@@@@@@@@@@
// ,"..--,[fzyfTifyuUHAdQ@QMM&R$DGUeXhVCni=[>l]*(~+:+,-!`.-_**![!""r^!,:^|-];r'""*/~-(/;-(`",('(:-):;,_:;,!_!*(+*<_)+_j=>+<17[j=Tcccj}]i7tTt}{uxouyhkuzkV4hXX%SXXXKS5SK$P5A5Q9MNN@@@@W@6@@@@@9@@@B@@@@@@@@@@@@@@@@@@@@@@@
// ,":^'~7hjYY}tF4SGZeOG0&HE0EE50UkUzkzn1Y=++]()*_!_*~~"-,;,^/:+^",;`~|-"~>:;:|':/r.<,|":^'"^_-~:.;."";'*';*~^^);/;[+rY+[+>lY+lY7Y[Tl<[Y7TJtcfJJsVTyyynFFyh4hVk%huXF4XU3SSAHO$M@MRA@BM@@W@@&@&@@@@M@@@@@M@@N@@#@@@@@@@@@@
// -,^;_iff17itXOdO$D$&A5MORDDQZkkVyufC}Yn1<Y)r_((/:"(_._`~--l,*r'+!^~^(-/*",~/"^,+.+-+",(,'--^-,.",!^~,;;,,|;_<+r/l(>r<rY|i(1<j<T>iL+}jYT={fniYTt7xfzutyxsfyzsVwssh3oo43UZZ$0DD&#M@#@@@@@@W#N#@@@M@&@@@@@@B@@@@@@@@@@@#@
// :'_nF|xsnjF5AOX&DZHOE6$G$RQNDSVVy}Js7J1Y]+|)_/!~)!/_"(-*-+".^],).;:_^,+ "^;;-*,(:^!*^~;:,!~'^ -!**`/.~_,'_*^;<~~*>+;<r]L+<1][]YiL+]Y+fYT]7J1TYfcnJxnfJi{fx{VzysfChFVhk4eA$$RQ#WW@B@@NW@@B&#9@6#M@@@@M@@56@@@@@@@@@@@B@
// _:zJt}ut7}GOe&OH50HGA50$EZ$WG3hox{JJYJi><[!;]^*"=-;;;/;^;[^;"*<.. ;;';;.~'_!'^"~/':,^*^",*,'*`~~;,.!:,^'.];^*r_(*]r"|_,](]1+r]<j|[)j[[ll[+<Y7>ijLt=J=c{1TxtFi{x{uzyooPXXKDREA0NB@M@@@9BN@RN&@NN@#N@@6@@B@@@&MQ@&M@@@@@
// ~i1tnTftteRoMdOD9O3DQRRER$NESUUhyYc7cj1Ljl|](+*_/+*_:+^_!L*:^-j'^:Y^';_"^'*^*;-,";'"-:(-`+''^,,,*,`>,,<:;~=^*!7!!l*<>l_*Y;)]*(}_*</|j+=L]][<i+=[L<7)}j17Y}cnT1fnuyzFo4kZeKdNOWR9M#&@@@B@#N@&@@N@@Q@@@@@@@@@@@WBE@#@@@@
// /7Tj1={xy9h@dHeAX5KR05NR9$MES3wsx=7jLT])Y_r;(";/"Y;;=!*](|]_*;[-;L` |;!'^,),"~-_!:.*,`~,`< "-",-)-'|',_+""Y~r^]^;*(__|^(~L~l(>|+r)]Yr<L[Yl<L7)]+<><]ll7jliYTniTfxxuyVkUSG56DG90&&#9@@@AB@BBD@@N@@0@@@d@@@6@@@@6@N@@@@@
// y>c17fftdGA9EK$5dAAE99X&5$#Ee3Ftzxuct[Y+l]**|;>(/r!((/~(":["~!("+'~,Y-)`:~+,^;"*.-"^"^'+'*:*'~;~/:-+^_^|~~<^(/!(^__;^^^__;*)_*(+!>(<>]]+L[l<j<[>>++c]1=<Yijit=7}xnVzz%%eHZA0H0099M$6N#0#W@BQ@@N@N&6@@#M@W6B@@@@M$@#@#@
// sYT=isfuE5HEOKD50GPK5$55G0BQUkztCTY[=l<(|!*_:;;!""~~,/_^!:!;(",|-;~,),!^:~>""^^'"./:~~,!^",*:"!"_"~^)*()<|r]|<r<|<l]())|))(<<><+||(([r>[c+c]YLc<t<Ylj7JiJ1itnTnuuxsVokUH$5D$$EQNWWM&W@5@WQ@DMB@@WR#@@D@@@@@B@@@WB@#MW@
// tLfYFfcx4RZ5D5DAD%@ZZ99k5$MQ3kVtJ7i|<[[)(_**:~;_!/**_r/(+r*<;/)_;^^(:""(^~^,!^/,:";"~:-`!-:;:;**(*r)]+l[j[[1J7[=j]j]]l[[>]<Y+>+<><<|]><|=ljYl[=]jL[=f=c}TJJutt}fyzVs%XXeOD0d0OEBW6MQ@WQ@GWBE6MM#@0MB6@B@@@@6@@@@WR@M@d
// uLusTznzxP$EDD9$dhZe$D6%EH093CzFft1<<>[>7/*!~^)r*)+>/r+</+<>/Y(|;;(<_;^*,<~^*!*",r"^"~:-~,~~;/|+Y|[]cc==TTfJn17L7jJ77jj]j|jl[L[[Y[<l[j[jY[c=jj7JT1ln{tTsCytVuuuwUywXUwkXGOD$R0E&#W&0@&W@ARN$6Q@NRNE@9MQ&6BQ@@@B@@D@d@W
// TnVuussyhSO9AGDEd96dP@OePZ0HGe%ntj]Y(+<*(;_;+_]+]+jLllj<=Yj[]=]>[rl//(;*;)*~(>*!^;;,;:,!_*/([j7=f7f7CCxuz{uCysx}xfnJn1ic11xtJi7JT11}7tJJyi}C}7nhnyxzsuyyzhFFoyuhXk4XX3ZZHDHRRQ#BMB@@N@&#&@6MQE@d@@WM6@@MWWM#N@@@@$@R09
// ==uCFXsUw%US0dRNHd$RoDAe5AHG33otnYYLY[||]|[[Y[L[]===11Y1nTTi{Tf7T1Y>>(/!*~/^!Y__)_*^*!![_r+|[tt{xxz{FyykhwhyFwhzVuyxVsCuxyCCyzzFVusyuVu{sCuV{y{oywFh3yV3kUk4FhUUk4w33SHKO5ZKOEE&RW#@0@M$B@DB@A@e@QR&@O#NRR6N@0#@N9@@D#
// uCVzoskSkSPAMEDXZ&E5kHKGHKDAPyF{kx17J7]}=Y=ic111JCusCsfhyzhsuxy}zf}jcl>)+(]*[/(_]^)()r)Y+>LY1iusFFkFUhk%U4UUhooVFXXwwokyVoXFUUXXeS34UP4XwkoXPXF3%XXK3GwKP33SwHFSU34FKSSXZG$A5AEB9Q@&#R9eWMWM&3@9@MBW@Z@#NB96W@Q@099@M#
// Ufx{zzX3P%oPKGWZAQEP4$KGGZZPZ%kUkxwxyuxsxss{hhwzKkyFVVfzz{kzos%oyVzutf7}+))(/>!>(r<+]|<j]Y1TfVyUkwXUSSZZKP3UXhXVtnn7Y][+Y[=L=ittsxhyoA5eODDAS$3AdG$ZADG5AOSHSZueXXP3SGZAGH550E&NQNR@@@NB@WME@N$W#W#M@#@B9@Q@@MD@@@W6@@
// uCfssyoe3UX4GPAAeG$3EVZ33eSHS3FyezhFUzVUUekVn=Y[+<]|<((r]lY[<Y17n{yuFwfnY+(<*l*]*<>r+[>>jcixFyFhKUwKSXKXUFhzx1==<]Y][7ij1=}{fffCshf{{y%FUPOOG$e$eHXG5$OOGK5534Uw3ozw%USXSXHXAeD$00&9&#d$B@0@5#d0Q&6HNQNe9MM9N#G@B@EBMN
// 4CxkkyAVk%HVe4G$AS$OU3SHOA3e5kyyzk%UXy%33st}7i}fCyoeZ3oPZKPPUXkff}1x{z{{Tj|[|/()*++/+]Llc{nsVUVUXGP3%h3ysffTjT7JuyhXSe$35GDOO3HAX5AZkk4kFXSS3Sh$ZAKAeOGSAG%%oko}yuVFhUF4h3ASKA5$DEE9BBW@@M9M6E9X@$9d&dNM$N6$R6@@@M9B9@
// oswyzSKk4VPE$05HedAHSfGOASP3HSyouxXkkwkkC{y%%UkFsCnxk3XKK5KZw$UGAKoCJfnxznf<=/)";);((]]<cV{UUwCxfGP4yxy}uunCzCVfuTc7Lx3eXGdOAOA5kPKKSXSAKK3PS$yZSHeF$U3zSoF{f}xit}xCfzyUyP%3eAOAD06$6MN9&EQ5&OEd0&d6&EDMD@9&BMG9#&E@#B
// hwyk%O3GOdSHAQZHRS0ARuOHHe5eH%VzznukzykXXVXwx1Y[L]jcy$3G%HK5HPXUoKoPwz7[nz1]Y_;!()!;r>LlJyooXPysh3%CiTzyf{}1Y<(*||+/<iFAP%XASAHkoXAUX4h3Vk4kUk343%ouxu{tnn}iY=lY=1TJnVszokSXZ5dZOQ0E@BR6NdQ@AB6R@dNMRNN&QMd@@@DB@W69@@
// LukyhKeA0E5A0NOEe55D9OPAXOeHG4n7L7=1[f=ffc[Y1]<r+r>l[u%ZPUk%ozVkXy{JJ7j/Lf]L+'''~~";_([=7fChxohhhuzucncl1[l*(*!"r/L([<<noFyUyhsVuF{xxttnf1}uCnT=[]<Y+l<[c|+Y<]<<[11n}VCoVo%43KGH$0EM9&N#@RB&06QHRD&&@FE#@@RW9@@B9E@Z@@
// f4XzAeSADEDPHKAASAEQ6&4dAAH$4V{ni>=+<Ytcfl+<<(+~;_^*^+!*+)<[Y7i1T[Y[<Y][YY>l+:"~;,^;_+l[TJ1snyfnxy1z1==][/=<))r_||+>(+*+<)[[]l1L1Yc==jc=T71J717LY=l[[][<[/+<>+]jL7=iuCCshwUKKZG5&$E6WWNBNW9$R6B5GBMQ@O&&$@N@QW@@@&@$#M
// UFoZHPO$X6X6Kd5R9N&5EQ5$DA0DGyT}f[[Y<[LJ7[r>+]/*]r())[+jLfctffsiTcc]lJL<]]r|("*,;^~;*)j7}snuCofufw7un}}Y]<Tj=][>]><l><]>L][YL[}==7TJ11T}fixi7j77cLLL<(<<<*)rl<+==j1iuuuhsU4eKP$EDdR&9BW@#dW6&@M0#N@Z@R0MD@#@H@6B#9@B#@
// xFFFDAEDAR50S9O@E0dRN0RA&0AEHC7+i=>l>1j[+)>+Yl=|c]}1Jn1nhozhhxJ1YYj])Y_Y<<+*+!_;"!*_([]]ns{zuy{oiuTVf7TY<>=<=Y<]=l=7YY[c71=i=Yj=1}sy1nttf]=<7|j(l>)*rr|+))r<[>[cjYc}xfFhUHKGGUd$MO6B#@#M#E@MB0MN&@@5@@&G&Q#RB#O@WBWR@@
// nkwzRO$QHA$@$OZNE&$E@B5$9d$E5xtJl><>))]/>/*_+(/r<<<L[Y711YYc[c[[]>(_*/*l!|+|<Y>**_!/*<]=Juiuxf}y1nLV17JL[|]r*j(c]]<cl=T[Y1ljcj7cYl=[>+)r_(!r)rrr*_||)([(rr]]Y[=Jt7fffyw4hSPe0d$WQ6WM@B9R@QAA@M@P@0@95@S#@$@Q@RE@@9@&@@
// {sFuZOKdEGEERDGMNR&NBWQ&W9E&GuJ1+L=*+/|/*!+_;(;~^;~^^;*<[+][![(+r;!!>*r>|+)>L<'_>;r(+<]n1nifff1u1zYk[<[]+((*)*>|_^*))((<^~~;(_;"_-::"(^;!(^_*(**r^/(|]]j[]j[=l1cicJzxoFwXGGA$OOR@@@B@W@@@@@5@@WR@6@@k@WA@MN&@R9@@@@G@@
// wyxooH$09BQ6dBH&QOQQ@9QMR&dN3Ft=[+j*r*"[*;"^_^*";;~^-~"[!!!*'(:_))*![*]rrl*)=+),|;_+|<<==]T[ji=J===Cl++l>>_*^;_^,^(;/:',!-~,~;^":':r;*^:)_!~/!*||r<]Y[[]l<[j7if7Jn{VsUkoeAeAe6dNB@N@@9BR#@9@G@@5W@A@N9@X@O@R@@@d@@@AN@
// XkxVKX$M&B9#OQ&$N0#6M966HREQZw}7l+[>+(_j"*^+^~:("^,~_^`:>:~/:*_^/_^!*]r;_["!;/L_^")++)[cjLYclYYJjY[l=l<j]r;>:*^^""!);~''(''"':^'^.:/(;,-^r^!*r!/))[L[ll=YL177inftxxVs4k3e3$AZ$ERNN@@@&@@d@@@0MO@Z@@6@@@$@5@@O@W9#@#@GE
// Xhu%UOV6$WW&N6d6W&@RMW0W@BRPRhu1=Y=<j>[|]~~;*""~r)_~("!-[/^*!^)'"+"^^(^;^*~_;!r;-^<|r+1)[<]j7LiYjjL[L[<1((!)~*^^^';"+"!"|!',''^'-!-(;;^"__;**()>]<<[]YjliL7c=ufT{CowUUkdZHZ$dE6@BBB@B@B@@Q@&@@d@R@@@@M&@M&BM#O@6@$BWBG
// zwkyUFwER#QDNBR60@MNNWBW&WB&$UsxjTYLc][l+<]<//*;+/""/'`-l,_;."^"_+";|*^(^;,_:r-'"~!((>L[)[)jcL[[jL<)j<>](/^+~^;":^^",[-"-[,,";-;*)^*"^^!(">!;+|<[=]jcLLc1=1T7fCfCVokXSK3O$E990@RW@@@@WW@@P@6@Q@@W$@#Q@d9B5@O6@6e@BWW&O
// h}hw39QHA9&3EB$HA@6MN&R@WQ@Ndw%ft[T<[<]>^j;)(~;*","'r^^.('-;:!**;~>;]~;/,r',^,, ",^^rrY>|==[t>+7<lL]+]rL>!!**;!((!+;"^*r;-+.'';":^((**!!_"!*;|+L]LlYc7j1177tffufz%w%XSePD$DA6RBWBMM6@W@@OE@X6@N@@P@6DN@KQ0@5@R@@9W96P@
// kVSHZkW$Q0&AAd500@ERQOB96BQ9&A%Vi}=L]>><!/!r^(_Y!^",;/;"/"`~~"~^/:"r^',-->'':`^`;(!*|)/)7T][LcYJcl_L]]<*)"^^!_^^!^=~!^;)~,;~-:";";)!^>^/(*_|(<+1[Y==c717JyTCsC{zkzX%SP550&K&WB##@E@9W@#R#RM0@@P@XR6@ON@GBMP@#OO&M@OBEQ
// A%55K5S$0QZM6&M0E&RR&eWQNREW6&eefi[>>)L_;_"~~"":~`''->-:(*,;|rr:+;,+^**^;)^^"'^,"_!*!Y!<Y>c==1>F)jY+<_]+_);^(()+!'_,!/'<~~"('~:/~!)_;)!r_*!((r<+]]j171JTfsfFuxCU%kw43XO5E$6OB#W#@P@@N6@6N#@N$@@B@A@N@N5d@@u@&A@dMRBd@4
// ReAAU6kRQ$X0Q0Q065ddeZ4GBQ@@6WZSCJ1jlr+*rr~_!/~)";,(^!/-]**r";*:]~*__^;^;;'^r`*~^-((|<*+]*1|JY<C+[=Y]|)><//;);(Y^>|:>!*/(+^-!':(!<^*~|*;/_/)r+l]LLY1=1tinzuUCsk%UUU%5Z5$&E96WBQ@BM@N@@@9#@W@H@@@dM@ZN@Z@@G@BB5MMR9@Z@X
// EZAESEQWQ&XWRQAWE&RE@B@$H@@#6QQeUox7=L>!_/;_"((((!~^"~!~:;,_"/!_/(j()_;,(r;`]!-/^r'(*1/=[=j<J]ju=1cJL[|c|;["Yr_+*;]_r<<!),+";,;)!/rrr+*_*+|]]]j<<i7Y1tti}hkzwzU%4XZHedQ5669MW##@@A@@dd@B9@N@&@&@A@5##R6W@@Ne@Zd@MW@e@D
// 3eE9EP&dEBGBRM000RA@QR9WGE&@&&EDkox77L])/+**;^)!;!;_;^!~^*~_!*(;|~1|r)!;*/'~"~"/:+_/<<<+]Yic71Y}=1jJi}<|+"l"!j_*(!+*^;/*;!r":!+;r+rr+r(r)>><lLj=j1i7nxnny%kzFs%%USS$ZO$d0MN9B@@@@@@@@P@@Z@R&ABW@3@#@E@&N#B@4#K&MB@MW@o
// k65d5#UEQMERZ06NBBOQ&RB@BB@NNM$OeFoJiY1]<[(//r;^"^:":*"!/__!/+!|||Y])|;)~|"'::.|,_*_r=Y]L]Y]YY[i[[Y1Ti=]|~(^r"Y-!;+|*r)_;"^^_^>!/((]()+>+<|[<Y=Jc1tt}unV}Xyz4whkKX4Z5$RR&N&#6@@@@@#@MR@WR@@@9@B@@V@@@G#KO#%B6B@B&6B95&
// 6%WdOEXMMQE9$9Q600NNM#&BEW6BE#DG04yz}T}j]7++*//^"^:^;;_;+**!(|()|i]+<r"+`~^^/"!"/!!_]+)[]17=j7]1[==itTCil^"*^,<((*;/^_;[",!:~;!r(;<<][l<<][YYYT1ixtsxxxyCwUFVyFSZ34G3DddE66R0NM@#B#WQ@@@N@d@9&6O#E6@@5@P@@5@AMWABB66BQ
// 094WQNU&BDX$50$&D&NBW9BE@ON@0BQQ04hFxCJ7LY>+*|*_!*;;*/*_>rr*|/]+<71cY>*_:;,_:r~^(+<[j1tufxuyf{nuufu{yyFf1r^_~!(^:~;)*;~*(!(/r+/+(>>l+]Y]T]=Y7iTisfu{Cuswyo%UyXXSeUS%KR9$Q6MW6WE@@MEB@&@W00@W@4@Z@EW@#@K&@9&E@MNPWWB@$@
// @W3@6NEX@ARNE$&#&6R#B&NH9N#&W@@E9dUwVuzTf7j]l+)(*|/)(+|r>>>(<*|>]>nwsfL>(|+r!(r[=JutyS4XZ4K3PXU4%kSXPkPK{+*r"",|"_~-(**;/_(())))[>)>l+l[7Y=J1f}f}{{uyukVkwUXFK4GZVHS$96QNMQB@#@@#9@A@@$@&@@MBM@@0@0@R@GD@A@QD&#HNN#@4@
// E0w9&d0RDM@3#N$M@Q9W&MZ&UB9N#66@@DG3XykxCn=jL[+|r+|+[>|+)(+/r**+/+<YJshh1]j]jj}}sFXyzUKdS$HSDPQoOz$5dFSh==r(_*;_,"^;*;)*)))+|<<++<+]Ll[==7c7nnfuJsz{CFwUH{SH4AUG$3D$9P&$MQdMW6W@M@@@9@WR$@@$@@MW6#@Q@BR0@A#S@@Md@@O@6@
// GNSERQdHA@@E&BWNEQQR669@X@@&0#@W#MG3UFzh}Ji=1l[[+l+l[]><+|*|/*;)^;r^~!^<7sonUt4sSPKHhZK5KeeD4KOK5GPGPFyui=|*)!!*!_*<^[)>>/j>]<[][=<]7LjfYi7tffxsfuuoyVwUFs4XeS%HAeHGQAQdM6NWW@E@B@@&@@@D@@@$B@@9@BW@$Q00@RH@Nh@@N@H@@R
// @BEXMM6X9@#@M@0@6&AAQQ0dR@9WRM@$#60e3%kwyCf11cYjl1Y<Y]]Y[>)<(*(;*_~*",-_!|YJh{XP3AXOkAP$eGZGX4ZSSP%wyCf=7j+<|)((((]<<]l]>L<+L[[l[lLYLjcTc=}7}{z{}xso{VF%wf%keUKCOHHER$&MEWE&B#B9N@Q#@6#@@@B@@0@@R@$N@A@WWE$0W6@@R@$W@e
// @Q&PZd#oM#@Q@@6@NM#9BMM65W@A9@NO@9M$HUzhkwfJiJ711i[Yc<cYL<><()*/_(:;;"~_";^*<[tVoPPZ43UKPKXXs%k{ys7T7c=<L>+><>||<>[YlLlL[YjlL]jLY]jY=j7=17fJnuzCy{zy{uykFh%yPFZUZSK$HR9&&#W&&B@@&#@@@@M@@@5@@R@@9E@9@K#@RBMB@S@@d@@@DN
// #RGE3W3HMQ@y@@N$&MEB9W&9R9R6k@RE@N&$DSkVyzft7iT1=ij=ijcYYj[<+rr*/(*!!^("^*~*]L7Tuxszss{VFyzzt{f}t17j7Y=<]YjYjLLl]Y=t71LT71l1j=7[[]lj[=Yc71f7nyCynyzxyoVkVVVuS4h345GZd5&&&B6NM#@#&#NB@0@@@@6@M$@B#NB@@A@M$OE99ABM4#Q@S@
// GeNOADDG&6@V#6MG@&6R90eRQE90SMNMW0dREeXVV{}jJ1ci1Y=YJY}<LL[lL]][)(((!;;;^;^|++[7tcTi1i1in}n}iTf1}7ijcY7Ycc7ijT1t1JCT{ftf11jjl]L[L<[[j=7jc1}itftCCVFfsUwwUV%{SUuUZZ5DA0Q0QN@NWW@B@@@@6@W@@@@Q@W@M6E@@@6B5@@H&@N@0@Z6@E@
// 0QR&h@BKBd@P@R&$M565EW0GR&@9$Q@QD$WM6QDhwnf7t7==7][[Lxj7===1JiT7L><((>r_(()((|(L<l]ljL17{nfnfT}inJ1it}n}}xu{FzFsCzf{nx711=]Y][><=L<|=<=Y1c7f}}ffxfz{hzokSzUhP33PZS3dd$Od&&6B6WWB@@@M#@@@R#@@06&@M@#@WNW@&NR@A@0M@R@@$#
// dD&AkRWKDR@hWdDSBEAHDHeOdM6#&V@@eM&Q60DXoC{j1c7c=Y][=[[1c1c1ysoXsCFuu{n17c7=Lc<L[L1J}TfuzsVszsyVVVy%ww%ww4XSXXHO3kC}=fl=<=<>Lj<[YLL<j[YjTJ=ut}J1yzyzzwwSU4fUVUFK4A5$$Q9R@dWN@@@@W@E@B@#@@M@R6Q#66Q@MD@@dEWS@@dR#NN@MW@
// 0E9ENh@ZA0@wMM66WWWMQOA0N#Q@&QZ&@3@@&W$PSkFfJi1c7lj[[><LicJJz}hyVzyhhzoXxVSssCfftnxzuCoFXokVS%XoUeo3UyPoekZAA3oV{fj7L=7LY+l+[<[]][1]Llc[}j1inJTyCVyyX%koS4kh3S4OSOOQQ66N@E6W#WW@N##@@@B@@W@@@E@@&@@6@A@AB#6RN@@W@O@M@B
// &GdDOoQ&55&5NKD0$A&9&DR9QNQe&WAQ@w@@0BBeSHhC{i1cY]]l]><<]]<YlY=[|>*^:/*L|rjr=|]=J}yVs{u}snsCzfnxuFVsysyzfn}71cLjcl7=j>1L<+||+)>]+[[L[Y==f=1TVTnzyCy%FkkyoUu%w53AX5HD0&0#6$&$BW6BB9BN@0@WWWNBWER@QB6@@NH@G@$MQ@&@&H6$@W
// RK90D6Fdd9@h&6Q$$EM@@QR$6&@%@@XW65E@QB&MHPASkCJ1jjYlY|]]</l>[r+(~!!-:)^r(/!>^/_//+]+]+([[Lj17711ttJtf}1f}J11j[<jL[1[Tll>l]<r]++[>]=Yj=1tTJt}w7zVoCwX4k4o4Xk3h$4KODD$699BQMMWM@BM@B##Q$@#@%@9@@R@BQW#O@A@DMR6@D@NDW@0&&
// o$HdA@VQ$Nw5dRdN$$MM@WWBMM@N$B3$&E9B&WRW#6QHe4yxJi7=Y[L<Y+]]|||_^^~;"/(!+]r<++>+<<jL]L]Lj==iicT11n}J{xztic==77lYc==l>Y<Y|]l>Y]lLL=jY7J7t}nJ{FnozwwFP3USXPXUekdeZAOEdRR59&NN6#M&@@Q@5R@B@M$@&@#d@@0@MO@9@Q@S$@#BRM6@B&@
// U5K$ZAKA0EwERZGEWEQ&E@@E6NN@H@0@M@0&E@E&#M#BZ5Soyfn7=jt[Y[]=!<|r*/_(;+r([+]Y=17Txxfxs{f1Cn{uuxyy}fsf{}{}f}17Jt7TJJ1i17L7<cLL7lYcY}17ixTfxxCshzwwyXkXwe4XGHwe%DQkQZRNddDE6B#W@@M@9@RBBN@9B@#R#@E9R&@e$@$#NW#E0B#W9#dNE9
// eGZKHSeEDR9Oe$Od@X@66NMBWEM0$&E$@@OWRNB&$BAWN&DX3Xy{u}}i1jY=Y[<]r[~_*]*)|>|LY=1JsVyhzFnyVuV{yCCf}t}ixu7nnTfC}1tJ1iiti1YY[c7=[=YTYf1JnC{zVzVukkU33XXZkSSAHewDUGdP9$0Q$E0&M6NM#@@@#@@@@M@#MM@D@#95@G@@W6B@@d@B@O@NQ@6#WW
// XXDUQRy&HD9&HR0EN5W9M@MR@R0MWENW3@RQA@WRWRQW6NM0ED4SuVVJf11TLLi<<<(r)[+_)!)<][Lc=11ixTu1}TfJJTt1}71cc77}17}71cT1c1}{11nc7Y7icJT11u{uxu{ukFhh%UwXZKAGSAPOKP4DkOE3ROWRMW0NN@M@BQ#@O@@$@B6E%@@B@Rd6RDBD@@X@@d@d@A@B9@@&#@
// DGOXQ&eR650WANEW#9QWW@Z@NN@W@HB9@@K@3@QBN@9&@@6&@@&OG4H%%s}fixcc7L|)*=(+|_^*/(r*]>l[]=]<[l[YLljljL=lLL(1]C11T{Tn17i}t7tJiTtTtfnxJfCFzzowSXSSSAkHAZ$GAODO$OkQhRGe9$N$W@N6B@@#@&@@@@@ZB@9@R@@@M6H@@e@@@S@@@WN&@@@#@@@#Q@
// sSKz6$4e&9RQDR#&MB9@NNMW9&$@BNB@@MROOM4@$@D@MM@RBNZ@W0UDAkXzxJiY7[L|*]**(!:~^,;~~:;:!"*^!"*r/*r)|+]]]++l=ijc7t1u7t7jf7fcTiittxuyuhuykh%%3KSKPPZX5K0PD5Z$AOX9k&NAQNQQM##W@#@@@N@@@#@@@@B@@WR@E@@B@6@@60W9@B@D@O&Q@@0@@E
// zZGZkXD4SQQSW0Z96OdMQ#@dBQk@#@@QW6#@GdEEQM3&N9S@E&NQB@X@&05AewCTJcL](|_/^*^:"-*,*'*^"""",^~*_/)(]<LcL|[7L11=Tt71Y1i7J}ftJxunxuV%VFwk%%SKGXZ5ZXeKAA5d$Gd$PDZ$UODG$EW9N#NQWM@@@@#@@9WN9@@@@@d@EBX@6@G@@0#@BN@M@@B@9&G@O@
// yZGU3HQGH5AUWQG@$B&D9&N0W9%BMRW9RNMM&&B9MEWN6#e@H#@KB@Q@d9DQRdZS{u7Y][r+^/*,-~",*;~,~"~,!"^^(!((<ljjrt]7nj[iit{J7}tJ}Cn{nFuFsVokkwXXUSAXGGOGA5$5Z$H$5GD0AKOD$oEEQ9&N9W@B@@@@k@&@RN@O@MM@W@Q@@0@@@@@d@%M@d#6@@O#BM@@R@M
// zAP%P0QwO$&G$9OBD@&O6dRE0RZB9M@eNMGBW96Z99@6@WPB@9@3R65@@K66RZEDOXh}fL[L/);_;!!;~!^^":^:_!(_|!>[>T;{]nL71l1ii1hcJJsxfuVzUySkUwUK4KKSH3AO5HOdO5GD3AeA5eAH0A5R9ZS@$M@6@6D@@&B@A@R@9@6M9@@0@@#@BE5&@&9@BW9@@@9M@A@$@#GD@@
// keS$U55Ak&D$X6DBGQAd&RNA0WDMQ6@D$E&N0d0PE&@NMB&W&@MS@9R@#Q@66Nd$Q$dUyif}+l|/r!+/(/(__!_^*(_]]!c]=Yl=Y[T=cl{JxuC{CyzwFwFUAU4SZ4GDPPGXZHHOS$PddZ$AADdZ53d3$5M0QdKMMM#N6@&@@W@&@@NR@@QW@9@@@R@@@@W0@$@9@@@@QNMQ@0#@@&@6B@
// 3kEAR%99%A$N3&QQE9ZQ&Q69RGM9Q@&d&0dD0Q0ZW9@Q$NN@$@4$MNRQM@QW9ERd&dQNz6XCC7=lT)]<+[*]+<+|]]]Y=<=cc7[icJ11n}usFhUVwhUUFS34PPSSGXGXPZ35GDA$ODeAODAPdD$GEeRER5W&K&SW5B69Q@WM@N@HB@M9M@@@@B@0@@@N@@@B$@@@@@@@@@WWZBe@@QOOW@
// e5Ge60XN$GDdK#AM&Bk6669QWN@@K@M&&@#d$9Z@W6##@E$@@@@G@N@QW##6@R&E6EM@X9EeXCkx}nctj<)1j=YYY71Tit7innfsyn{sxuhhXUU4PXZZH5HA$5KK5AUO$H5EKDK55HPd5HDNdO9&H&AQ#N#$O@X@65#d@@A@@@6W#MM@@@@@@N@@@@@@#@@@@QW@@6@@@5W#@B6@dD@UN@
// KE5AW&zd$9AdGMoDRE60Md&N#@@#DDRNR@59R666M&W@BQ@B0@@U@6@6@R@NM6#0&RM6P9W0PXKUFVyhufTtt}uf{fxftzsykFzkzVkUUkSXkkw%PZAK$HHGeHOH5AGkOZ355ZADAODeD5EAQEMQK09RB006O#P@MQ9EWE$@&69BBBBM@B@@@9B#@@@@N@@E@EBW@B#B@@@@6#@M@A@@K@
// FDeeG6o&$5HH6WKD0WB@#$@W&EQ@56@@@@GBQ9N6NW#@@@@@MWWE@@BQ@@@B@Q@6N6W@306dD9ZRHUHUU3GUk%wU3XSX%kkX%ePhPGXGPX3PZzAkPSPKe%4HG0DAKU5A55AHwA5HOD$056D@06WMMHR9#66WU90M0$D5$O&NU#WWNH@@@W@@@#@6@N@@##@W@M6M@@@@@#O@D@#6@DG@B@
// ASAOD&4PO0GG&DKDN$EGM6OMEE6N@@6#@@OB@Q660N&9@@W@@#BW@O@R@BM@@$M6&eW@HQQDO0EN0}65F95ShAH3HeSG3KZDzKKG%K4KKXS%H%ZeKO5PH5UOPOAAHGR5e$OO$XQd$A6EQ0E&HBOQM50RQG&EPNhB0DO&HBNdGMGN&d@R&@M@&RB@9#@R@@@M@W&B&@N@NN@M#dNBd6@B@U
// RSEPD9M%d0&5dM&KEE@A@eB&WRQR@@@@@@B@W9$6d@@BWM@@@@#N@WN&M@@#@@6M#R0@dN#eN&0RBO9#oR9QsO$S6G5dSdA$kRdOSOOZDQ5G$dGAKDGHAe0ZQE&$K$SBH&9OBGAQK@MONP@P6RWXWRdA@3RM&EHHNEX6Z9D9HWB@9@6&N6BMA@d#N6N@@@@@9@M&@@W@NN@@Q@QM9@@O@B
// DSAHk5OKE5QB6W$#O$NMNR@@SW0@@WN64G6R@#N@@6@@Q#B@@@@@@@@&@@@e@@9#@@#Q@@@4WR0WDBS@G6BB$ddEEU&d5Q$D39NWwEX6DZOROA0DU$PRSQ9DZ&eNNOeW$9ME5#SMh@N66Q9K&R90$D9eENDMR40X6&d590DE9d&M6EB4#669A@&Q6Q@@B@N@@@@W@@#@@@@@@B@H@@&9E@
//
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#M&R&@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&&NMWB#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B69RRRR6B@@@@@@@@@@BM69QQ6@@@@@#BWMMMNNMWBBBWM&&W#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@9QQQQQQQQQ96NMW#@@N9RQEE0OAGAA5D$0EEEddd$$DOOOOOOOOD$dd$O5ADRM@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WQEEEEEEEEQW@@@@@@@@9QQQEE0OGGGGGGGGGHHGGGGGGGGGGGGGGGGGGGGGGGGGGGA$B@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BR000000000EB@@@@@@@@#QEE000dDGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGAd#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@90000ddddddEB@@@@@@@@@6d$$OAAHGGGGGGGGGGGGGGGGGGGGGGGGGGGGGZZZZZZZGGGGGGGGGGZH0#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WEEE00000d$ODW@@@@@@@@@@0AGGGGGGGGGGGZZZZZZZZZGGGGGGGGGGGGGZeeeeeKKKeeZGGZeeeeKKeeGD@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@6QEEEEEEEEEEEB@@@@@@@@@@@0d5GGGGGGGGGGZZZZZZZZZZZGGGGGGGGGGGGGeeeeKKKKKKeeZZeeKKKKKeeZH6@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@9QQQQQQQQQEEEM@@@@@@@@@@@W00dDHGGGGGGGGGZZZZZZZZZZZGGGGGGGGGGGGGZeeeKKKKKKKKeeZeeKKKKeeeZG$@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B9RRRRRRRRRQQQN@@@@@@@@@@@@&E00d$AGGGGGGGGZZZZZZZZZZZZZZZZZZZZZZGGGZeeeeKKKKKKKKKeeeeKKeeeeZZGHR@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@M9999RRRRRRRRR6@@@@@@@@#BBWMQEE000dOHGGGGGGGGZZZZZZZeeeKPPPPKKKeeeeeeeeeeeeKKKKKKKKKKeKKeeeeeeZZZGN@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@M699999999999999966&&9999RRRRRQQEEEE00dDHGGGGGGZeeKKPS3XUU%kwhhFVVVVFhowwk%UXSPKeeKKKKKKKKeeeeeeeeeZZZA@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@0@@@@@@@@@@@@@@@6&&&&&&&&&&&999999&&&6&&&&&&&9RQQQEEE000d$AGGGGZP3XUUkkwhVzuf}Ji1c=L[<>+YiC%Z5$d9M##BW#@@@@#0HeeeeeeeZZZZ$@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@WO@@@@@@@@@@@@@@@@@@@@@@@BW6&&&&&&&NW@@@@@@@#W&RQQQEEEE0000$HGGZKUzzyzzsCxJ7Yj7}uVkG0R@@@@@@@@@@@@@@@@@@@@@@@@@AZZZZZZZZZZZGN@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@$@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B9RRQQQEEEE000d$GZePFl(1wKDRM@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@HZZZZZZZZZZGOR@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@W9RRRQQQEEEE000dHZeKy" .O@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@6ZZZZZZZZZZZH$&@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B@@@@@@@@#@@@@@@@@@@@@@@@@@@@@@B&9RRRRQQQEEEE00dOGS{   E@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@AZZZZZZZZZZGH$&@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BM6&96MMN66&&&&&&&&66NNMMWBB##@@@@@@@699RRRRRQQQQEEE00d3}- :@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&ZZZZZZZZZZZGA0&@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#BMN&99RRRQR9999RRRRRRRRRR99999999&&&&#@@@@B6&999RRRRRQQQQEEd%tj_J@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&GGGGGGZZZZZZG$E&@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@E0Q@@@99RRQQEEEEQQQQQQQEEEEEQQQQQQRRRRRRR99N@@@@@#6&9999RRRRRR9&60UyVo0@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@AGGGGGGGGGGGGGG50QW@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@000R@@@EE000d$DEE0000000000000EEEEEEQQQQQRB@@@@@@@M6W@@@@@@@@@@@@PXSe@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WHGGGGGGGGGGGGGGGH0Q&@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@NE00Q@@#DAHGGHO5AAAHHHHHAAAOO$$d00000EM@@@@@@@@@@@@@@@@@#WWW#@@@@eZH$EM@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@0HGGGGGGGGGGGGGGGGGG$Q9@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BE0EQ@@@6$HGGGGGGGGGGGGGGGGGGHHA5Q@@@@@@@@@@@@@@@@RRR9999&&&N@@@Ddd000Q@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&AGGGGGGGGGGGGGGGGGGGGGOR9#@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@REEQR6@@@@@B&$GGGGGGGGGGGGGAW@@@@@@@@@@@@@@@@WEQQQRRRR9999N@@90000EEEER@@@@@@@@@@@@@@@@@@@@@@@@M9$AGGGGGGGA$$D5AHGGGGGGGGGGAQ6@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WN6&&&6W@@@@@B60DHeA6@@@@@@@@@@@@@@@@@@90EEEEQQQQRRRR9M@@Q0EEEEEEEQQ9@@@@@@@@@@@@@@@M&Q0d$D55AAGGGGGA$0000ddDOOOO5555AAEM@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BWN66&N#@@@@@@@@@@@@@@@@@@@@@@OD$d000EEEEQQQRRR#@@EEEEEQQQQQRRQW@@@@BN9QQEEEEEEE0000000dd$$DddEEEE0000000000000N@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@GZZGH5$d00EEEEQQRRR@@NEQQQQQRRRR99999RRRRRRRQQQQQQEEEEEEEEE000000EQEEEEEEEEEEE000Q@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@KwU3PeZAd000EEEQQQQQQQ@@RQRRR999&&&&&&99999999RRRRRRRRQQQQQQEEEEEEEQQQQQQQEEEEEEEEE9@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@}YtukPZG$000EEEEEEQQQQQ9@@9&6MBBBWMNN6&&&&&&&&&9999999RRRRRRRRQQQQQQRRRRRRQQQQQQQQQQM@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@##BBMMN6&&&&&&&9999999RRRRRRRRRRRRRRRRRRRRRR@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#BWMM6&&&&&&99999999999&NMMWB#@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#BWMM666&&6MB@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BN9Q0$5AHGGGGGGGGGGH5D09NB@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@##BBWMMM666&&&
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@WW@@&EEd$D5AHGGGGGGGGGGGGGGGGGGGGGGGGHA5O$0R&6MB@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B&&&&&&&&&&&&&&&&&&
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@RQQQ6NNN&RRQEEEdDOAHGGGGGGHAAA555DD$$d000EEEEEQQQQRRRR9@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&&&&&&&&&&&&&&&999999
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@RQQQQQQR&W@@#WN&RQQEE0d0000000E9@@@@@@@@@@@@@@69999&&66M@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@W&&&&&999999999999999999
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@QQQQQQQRM@@@@@@@@@@@BM69RRRRRR@@@@@@@@@@@@@@@@@WB#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&9999999999999999999999999
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#QQQQQ&@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@M9999999999999999999999999999
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@RQR@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B&99999999999999999999999999RRRRR
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&99999999999999999999RRRRRRRRRRRRRRR
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@B&999999999999999RRRRRRRRRRRRRRRRRRRRRRRR
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&999999999999999RRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#W&99999999999RRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@#BWMNNNMMW##@@@@@WN&&&&&M@@@@@@@@@@@@@@@#&999996NNM699999999999999999RRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRQQQQ
// @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@BWMN6&&&&&&&&&&&&&&&&&&&&&&&9999999999999999999999999999999999999999RRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRQQQQQQQQQQQQ
